# %%
import pandas as pd
import numpy as np

# %%
path = '/Users/sayasatsabit/Downloads/loan_approval_dataset.csv'

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.columns = [i.replace(" ","") for i in df.columns]

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
df = df.drop('loan_id',axis=1)

# %%
df.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['education'] = label_encoder.fit_transform(df['education'])
df['self_employed'] = label_encoder.fit_transform(df['self_employed'])
df['loan_status'] = label_encoder.fit_transform(df['loan_status'])

df[['education', 'self_employed','loan_status']]
# Out:
#       education  self_employed  loan_status
# 0             0              0            0
# 1             1              1            1
# 2             0              0            1
# 3             0              0            1
# 4             1              1            1
# ...         ...            ...          ...
# 4264          0              1            1
# 4265          1              1            0
# 4266          1              0            1
# 4267          1              0            0
# 4268          0              0            0
#
# [4269 rows x 3 columns]

# %%
df
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          0              0       9600000     29900000
# 1                    0          1              1       4100000     12200000
# 2                    3          0              0       9100000     29700000
# 3                    3          0              0       8200000     30700000
# 4                    5          1              1       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          0              1       1000000      2300000
# 4265                 0          1              1       3300000     11300000
# 4266                 2          1              0       6500000     23900000
# 4267                 1          1              0       4100000     12800000
# 4268                 1          0              0       9200000     29700000
#
# ...

# %%
df.dtypes
# Out:
# no_of_dependents            int64
# education                   int64
# self_employed               int64
# income_annum                int64
# loan_amount                 int64
# loan_term                   int64
# cibil_score                 int64
# residential_assets_value    int64
# commercial_assets_value     int64
# luxury_assets_value         int64
# bank_asset_value            int64
# loan_status                 int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x = df.drop(columns=['loan_status'])
y = df['loan_status']

num_columns = ['no_of_dependents', 'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
                      'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value',
                      'bank_asset_value']
x[num_columns] = sc.fit_transform(x[num_columns])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
models = {
    'KNN':KNeighborsClassifier(n_neighbors=5),
    'RandomForestClassifier': RandomForestClassifier(random_state=42),
    'DecisionTreeClassifer':DecisionTreeClassifier(random_state=42),
    'SVM':SVC(random_state=42)
}

# %%
for i in range(len(models)):
    model = list(models.values())[i]
    model.fit(X_train,y_train)
    
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)
    
    model_name = list(models.keys())[i]
    print(model_name)
    print("Training dataset accuracy: ")
    print("Accuracy : ",accuracy_score(y_train,train_preds))
    print()
    print("Testing dataset accuracy: ")
    print("Accuracy : ",accuracy_score(y_test,test_preds))
    print()
    print('-------------------------------------------------')
# Out:
# KNN
# Training dataset accuracy:
# Accuracy :  0.9487554904831625
#
# Testing dataset accuracy:
# Accuracy :  0.8992974238875878
#
# -------------------------------------------------
# RandomForestClassifier
# Training dataset accuracy:
# Accuracy :  1.0
#
# Testing dataset accuracy:
# Accuracy :  0.9789227166276346
#
# -------------------------------------------------
# DecisionTreeClassifer
# Training dataset accuracy:
# Accuracy :  1.0
#
# Testing dataset accuracy:
# Accuracy :  0.977751756440281
#
# -------------------------------------------------
# SVM
# Training dataset accuracy:
# Accuracy :  0.9584187408491948
#
# Testing dataset accuracy:
# Accuracy :  0.9285714285714286
#
# -------------------------------------------------

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

for name, model in models.items():
    print(f"Model: {name}")
    model.fit(X_train, y_train)
    
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)

    print("Training Accuracy:", accuracy_score(y_train, train_preds))
    print("Testing Accuracy:", accuracy_score(y_test, test_preds))
    print()

    print("Classification Report:")
    print(classification_report(y_test, test_preds))

    cm = confusion_matrix(y_test, test_preds)

    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix - {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
    
    print('-------------------------------------------------')
# Out:
# Model: KNN
# Training Accuracy: 0.9487554904831625
# Testing Accuracy: 0.8992974238875878
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       536
#            1       0.85      0.89      0.87       318
#
#     accuracy                           0.90       854
#    macro avg       0.89      0.90      0.89       854
# weighted avg       0.90      0.90      0.90       854
# -------------------------------------------------
# Model: RandomForestClassifier
# Training Accuracy: 1.0
# Testing Accuracy: 0.9789227166276346
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       536
#            1       0.98      0.97      0.97       318
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

pipe_svc = Pipeline([
    ('scaler', StandardScaler()),
    ('svc', SVC())
])

# %%
param_range = [0.0001, 0.001, 0.01, 0.1,
               1.0, 10.0, 100.0, 1000.0]

param_grid_svm = [
    {
        'svc__C': param_range,
        'svc__kernel': ['linear']
    },
    {
        'svc__C': param_range,
        'svc__gamma': param_range,
        'svc__kernel': ['rbf']
    }
]

# %%
from sklearn.model_selection import GridSearchCV

gs_svm = GridSearchCV(
    estimator=pipe_svc,
    param_grid=param_grid_svm,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

gs_svm.fit(X_train, y_train)

print("Best params:", gs_svm.best_params_)
print("Best score:", gs_svm.best_score_)
# Out:
# Best params: {'svc__C': 1000.0, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# Best score: 0.9528550512445093

# %%
best_svm = gs_svm.best_estimator_
y_pred = best_svm.predict(X_test)

print("Test Accuracy:", accuracy_score(y_test, y_pred))
print(" ")
print("Classification Report:")
print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix (Best SVM)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Test Accuracy: 0.9519906323185011
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       536
#            1       0.94      0.93      0.94       318
#
#     accuracy                           0.95       854
#    macro avg       0.95      0.95      0.95       854
# weighted avg       0.95      0.95      0.95       854

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist_knn = {
    'n_neighbors': [i for i in range(2, 20)],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'chebyshev']
}

rs_knn = RandomizedSearchCV(
    estimator=knn,
    param_distributions=param_dist_knn,
    n_iter=20,
    cv=5,
    scoring='accuracy',
    random_state=42,
    n_jobs=-1
)

rs_knn.fit(X_train, y_train)
print("KNN RandomizedSearch Best params:", rs_knn.best_params_)
print("KNN RandomizedSearch Best score:", rs_knn.best_score_)
# Out:
# KNN RandomizedSearch Best params: {'weights': 'distance', 'n_neighbors': 18, 'metric': 'manhattan'}
# KNN RandomizedSearch Best score: 0.9297218155197658

# %%
best_knn = rs_knn.best_estimator_
y_pred_knn = best_knn.predict(X_test)

print("KNN Test Accuracy:", accuracy_score(y_test, y_pred_knn))
print()
print("Classification Report:")
print(classification_report(y_test, y_pred_knn))
cm_knn = confusion_matrix(y_test, y_pred_knn)

plt.figure(figsize=(5, 4))
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Greens')
plt.title("Confusion Matrix — KNN (Best Model)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# KNN Test Accuracy: 0.9227166276346604
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       536
#            1       0.89      0.90      0.90       318
#
#     accuracy                           0.92       854
#    macro avg       0.92      0.92      0.92       854
# weighted avg       0.92      0.92      0.92       854

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)

param_grid_dt = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 3, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

gs_dt = GridSearchCV(
    estimator=dt,
    param_grid=param_grid_dt,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

gs_dt.fit(X_train, y_train)

print("Decision Tree Best params:", gs_dt.best_params_)
print("Decision Tree Best CV score:", gs_dt.best_score_)
# Out:
# Decision Tree Best params: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Decision Tree Best CV score: 0.9821376281112739

# %%
best_dt = gs_dt.best_estimator_
y_pred_dt = best_dt.predict(X_test)

print("Decision Tree Test Accuracy:", accuracy_score(y_test, y_pred_dt))
print()
print("Classification Report (Decision Tree):")
print(classification_report(y_test, y_pred_dt))
cm_dt = confusion_matrix(y_test, y_pred_dt)

plt.figure(figsize=(5, 4))
sns.heatmap(cm_dt, annot=True, fmt='d', cmap='Oranges')
plt.title("Confusion Matrix — Decision Tree (Best Model)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Decision Tree Test Accuracy: 0.9836065573770492
#
# Classification Report (Decision Tree):
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       536
#            1       0.99      0.97      0.98       318
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)

param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

gs_rf = GridSearchCV(
    estimator=rf,
    param_grid=param_grid_rf,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

gs_rf.fit(X_train, y_train)

print("Random Forest Best params:", gs_rf.best_params_)
print("Random Forest Best CV score:", gs_rf.best_score_)
# Out:
# Random Forest Best params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Random Forest Best CV score: 0.9815519765739387

# %%
best_rf = gs_rf.best_estimator_
y_pred_rf = best_rf.predict(X_test)

print("Random Forest Test Accuracy:", accuracy_score(y_test, y_pred_rf))
print()
print("Classification Report (Random Forest):")
print(classification_report(y_test, y_pred_rf))
cm_rf = confusion_matrix(y_test, y_pred_rf)

plt.figure(figsize=(5, 4))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Purples')
plt.title("Confusion Matrix — Random Forest (Best Model)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Random Forest Test Accuracy: 0.9789227166276346
#
# Classification Report (Random Forest):
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       536
#            1       0.97      0.97      0.97       318
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854

# %% [markdown]
# __Before Tuning:__
#
# KNN: Train 0.9488, Test 0.8993
#
# Random Forest: Train 1.0, Test 0.9789
#
# Decision Tree: Train 1.0, Test 0.9778
#
# SVM: Train 0.9584, Test 0.9286

# %% [markdown]
# __After Tuning:__
#
# KNN: Train: 0.9297, Test 0.9227
#
# Random Forest: Train: 0.9816, Test 0.9789
#
# Decision Tree: Train: 0.9821, Test 0.9836
#
# SVM: Train: 0.9529, Test: 0.9520
